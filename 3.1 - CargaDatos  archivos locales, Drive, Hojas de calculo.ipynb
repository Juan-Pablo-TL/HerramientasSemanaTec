# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9d41db8f-d95f-4021-ad9b-4ecc5a9f6cff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d41db8f-d95f-4021-ad9b-4ecc5a9f6cff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book1.xlsx to Book1.xlsx
# User uploaded file "Book1.xlsx" with length 8287 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('EjemploSemanaTec.txt', 'w') as f:
  f.write('Este es un ejemplo de la semana tec')

files.download('EjemploSemanaTec.txt')

# %%
ls
# Out:
# Book1.xlsx  EjemploSemanaTec.txt  sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/MyDrive/SemanaTec/foo.txt
# Out:
# Hello Google Drive!

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: SemanaTec, id: 1vmRnYUaQRag1YLcvXzTOC0_qrqd5g9IQ
# title: Herramientas Semana Tec, id: 1lldwkBT-ATgKjIe9PyffHcVq2Eiye4zH
# title: EquiposInteconexiónSuelasElBicho.pdf, id: 1t7ZqhGRfDBRM4_vmG-p7IYlLwPQYs6eI
# title: EquiposInteconexiónACTato.pdf, id: 13vSOOWVuuWnAQEYH8kCLJ3PM5o4iVbrq
# title: VideoPresentacionEjecutiva.mp4, id: 1WUw9BC3SKE1LLLBpueGX4kSXouA-NQFN
# title: CoroBariJP.mp4, id: 12gaZAwOGsDEGcxU9uh8vzUiVryGXswHn
# title: CoroTenorJP.mp4, id: 1ngF7XYHRwAWZcuEzWtd3dsFTOPCYrtWk
# title: SomebodyJP.mp4, id: 10L2-gPmWGSUL6C6Dcz2UUd5MqJGeGMQw
# title: Another2JP.mp4, id: 1S5RlFMgnvThQ5cehCNUaDu0j8IQlcyUJ
# title: Another1JP.mp4, id: 1jCeXpLS5zrfSaZfj21M8ouiVXZtlE55B
# title: CorosBaritonoJuanPablo.mp3, id: 1WzL09zzqeYGSiog2H2RSCyESnnTqJU2S
# title: SomebodyToLoveJuanPablo.mp3, id: 1pQoBac-53_BwON6-K861kiCi9zF2x2yE
# title: corosJuanPablo.mp3, id: 1uN0ngMIOd6XYjbFjqQq8YmTjKUynC6QP
# title: AnotherOneJuanPablo.mp3, id: 1d7_l-zRtliiqI3ANzOzZ9ZPloLdhQVQz
# title: SomebodyToLoveJuanP1.mp3, id: 1W-2Px8V2ZjiqeXhYYXPQ5T-yMk0qhaI6
# title: anotherOneJuanP2.mp3, id: 196eX7YFZ-faaw_Oj24Angy35UKpXMQuH
# title: anotherOneJuanP1.mp3, id: 17aj5VgYCdmK4wwC6wwcRE8fzLhIb1J3W
# title: Bitacora 2, id: 1TVrvmhiWGCMOr5DWdDxusLhslsWG1UeYT-UGyWcOSRA
# title: TimeIsRunningOut.mp4, id: 1imgR6izkK2f4IDibES1IOcxJlGs8NnX-
# title: VocabularioCoreano, id: 1gdDFMmfE-B05_uit-2H5hISriTpdoO5czehapfLRAIM
# title: Situación Problema Biología - Gráfico circular 7, id: 1DGa9uMaO5J9-oPC0quTwZxlqyr_Tfj_mvgFL1PUhvg4
# title: Situación Problema Biología - Gráfico circular 6, id: 1NRi43oylzGGApFfR8RIgm9muMFzClzqqWshSifEfgWs
# title: Situación Problema Biología - Gráfico circular 5, id: 16gBnWrlzBAYY-1UDoBAWEuFDpyWuWuY1FWrUC4FX5Ng
# title: Situación Problema Biología - Gráfico circular 4, id: 1cqwMjjyB834hCQmCqZyq71yqzlH7sE0gwWj26137Vtg
# title: Situación Problema Biología - Gráfico circular 3, id: 12S1lVgHwxG-A6IDxtZWAUbCvuN-7v0VRPGy-W_p5ZjU
# title: Situación Problema Biología - Gráfico circular 2, id: 1hr97ikBO7w2RRucPz-TL6g61tMQgyMrxEX8G0njTGUQ
# title: Situación Problema Biología - Gráfico circular 1, id: 1N-zjMg5Ty79ZwLo-43SZ0GSUhsm5aZMsOGa6fvUsrvE
# title: Cantidad de casos divididos por sexo, id: 17DblfCLjRDQcnmX7P9AlZoR2Ds5Eju6F6ts3-ELCJLM
# title: Situación Problema Biología - Gráfico circular 1, id: 1sKgnerp_8gE4uw-j_pOvWZia-MotHagOQUvZijux2SI
# title: Reporte submarino, id: 1ZvB6siuogYIRkeEls9yedmOxOQ1GiX0tmmRH9120_Cw
# title: funcionpotencial, id: 1V108by8hPaOjrjm-6OkSLRloBRLJuUz1j56cVcTA5ug
# title: Ética, id: 1zR1VZpPqP0CEcLcrHLcjpDM2r0AMohxl7VtOtbif-mk
# title: China Us, id: 1hZk6F2NZFbInu2cTUSEj2AbXAZMmyqi9IemLjTswdh0
# title: evidencia 1, id: 1v_20ZfYuHbXcIYFW9raSfRcDV744nyuqFXDluE5HF6g
# title: Interpreta Tablas, gráficas, mapas, diagramas  y textos con símbolos matemáticos y  científicos, id: 11pftYivFjD5_hRJ-Ybn5PruM4HNm-I7LtMyL31uVzOI
# title: Analiza las relaciones entre una, dos o más  variables de un proceso social o natural para  determinar o estimar su comportamiento, id: 1-ekgUbDR9gT6RHP88nj3sD2HFcW_AmYksBLjNyZREa8
# title: Construye e interpreta modelos matemáticos  mediante la aplicación de procedimientos  aritméticos, algebraicos, geométricos y  variacionales, para la comprensión y análisis  de situaciones reales, hipotéticas o formales, id: 1FHbIKujQgyjeaj8MVfjv4xZaq64yb4HVyxEtAXDqO0I
# title: 3rd Partial, id: 1UMaEgDccP_RuDoN6WBP9n5fBHTGzOzWT5yNxjRjCt8w
# title: 2nd Partial, id: 1UBcrMS3wkor6gU8cFPmePvNkMwrxuE4lYWzC54LGq3I
# title: 1st Partial, id: 1kW3S7W_zM-Vr7SDGHp6Mjzvvvi84tAfczH2X4l3sk_4
# title: Birthday Polynomial, id: 1PCE52IsPHqO6kLdzv6T-kBlq1H0G6jnmp-Ipid3me1g
# title: Trabaja en forma colaborativa Asume una  actitud constructiva, congruente con los  conocimientos y habilidades con lo que cuenta  dentro de distintos equipos de trabajo., id: 1ZMAXX7_SD9iNP50azBq2j-VBw6LX8K_yxtP78nG1LLU
# title: Aprende de Forma autónoma: Articula saberes de diversos campos y establece relaciones entre ellos y su vida cotidiana, id: 1fMe-SpJMeJw3gqbw3sOXT-bRS9ValmFWgnnrEEkGNZQ
# title: Formula y resuelve problemas matemáticos aplicando diferentes enfoques. , id: 17sLA-WmWuy6ErKVcFk5kjUoveFNm49usbmk13HxF0sg
# title: Copia de Subtitled-The Time Paradox-720p.mp4, id: 0B_HgHKjpD_QxOUp5M19nZGNNaGM
# title: Proyecto Integrador Segundo Parcial, id: 1_XmYhl-eTTYO7oaePE_nPc0TcGQirYW1Ks5RnzhQtMk
# title: Propuestas, id: 1Rif7MVVJiXSvKxYZqTmAFQfpaKQp7br3JwoqVjq2gGk
# title: Proyecto esp Locura, id: 1FjCRg1SkFQpGi2wiiolrVTbKPH2SAEPfmEWdBC3jDxI
# title: 4_1_elementos_del_pensamiento.pptx, id: 0B_HgHKjpD_QxeU4xTmdXdTZUbUk
# title: tema2_ procesos_de_pensamiento.ppt, id: 0B_HgHKjpD_QxY2xkMTBKS3ZkZ00
# title: CV ACTIVITY, id: 1KDeGhkuar48px-Yn1P8P_v_BfMGurZ0CbmSbV9BU-mE
# title: Credo de Asesinos, id: 1rrzrurkhIz7Zw-RB21KN2H-cTk7gv6jzLjPCWXqTfMk
# title: Copia de Credo de Asesinos, id: 1tRDKOXeLt31zjz-4nF-vdkxBEFLFFDjQi7TXccEe9B4
# title: Oceanic Biome, id: 1o48oNGfZtK5hLhjxhCm_qITOs2Z7Jlc69tR8IVNM06k
# title: Mate darrrio, id: 1KRIOEZvU9Yojy5AuXnvIiJlwLq_Nob2DIkKgwo1FkQY
# title: Black, id: 1oktaPhIg9Nnk-4keWr0GQLroUBVhCNUVsR3dFGxE0mk
# title: Africa 1800, id: 1rpdLBxehAtQmDiPmJPR9xrl33hXhRSLz7GhwXI_xOYM
# title: What makes a design a good design, id: 1KDdSRfRXmrj0SsQ6mdDvL5qjsloVwccNS9Qa97jkKD8
# title: What-makes-a-design-a-good-design.docx, id: 0B_HgHKjpD_QxOUI5ZDlOcXFsR28
# title: Africa articles, id: 1F0SEEeJ0AyaTkdTe3brjgvdYEYNIsjSRpo4txZR3TIs
# title: Arte 401 Juan Pablo, Dario, Zaid, Rodrigo, id: 1kv7_J8JbCG3gQjpHW_QHZvXkrtK0hMqqKX4IO3BZj5E
# title: Quiz 2.2, id: 0B_HgHKjpD_QxOWZsT3EtS2g1NmM
# title: Fundamentos de matemáticas, id: 0B_HgHKjpD_QxRndYZEpuZFY5MEE
# title: Mejorar el salón, id: 1Prl675PbxKUhyzWdhzHr8q3AdXLyJoz1mLhXuhzENec
# title: Classroom, id: 0B_HgHKjpD_QxfndBMll2TDBzNTdXb0d0TG5oVDdMRGZiQlJCRUFjQ2hBTzRPOWRXcGE5MW8

# %%
fid= '1r3STNnFiq8uRhifgq96dbO2keF58zFqU'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# ---------------------------------------------------------------------------
# ResumableUploadError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     368       metadata = self.auth.service.files().insert(**param).execute(
# --> 369         http=self.http)
#     370     except errors.HttpError as error:
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     878             while body is None:
# --> 879                 _, body = self.next_chunk(http=http, num_retries=num_retries)
#     880             return body
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in next_chunk(self, http, num_retries)
#     998             else:
# --> 999                 raise ResumableUploadError(resp, content)
#    1000         elif self._in_error_state:
#
# ResumableUploadError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">
#
# During handling of the above exception, another exception occurred:
#
# ApiRequestError                           Traceback (most recent call last)
# <ipython-input-13-6e0aaba0a3fb> in <module>()
#       1 uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
#       2 uploaded.SetContentString('Sample upload file content')
# ----> 3 uploaded.Upload()
#       4 print('Uploaded file with ID {}'.format(uploaded.get('id')))
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in Upload(self, param)
#     283         self._FilesPatch(param=param)
#     284     else:
# --> 285       self._FilesInsert(param=param)
#     286
#     287   def Trash(self, param=None):
#
# /usr/local/lib/python3.7/dist-packages/pydrive/auth.py in _decorated(self, *args, **kwargs)
#      73       self.http = self.auth.Get_Http_Object()
#      74
# ---> 75     return decoratee(self, *args, **kwargs)
#      76   return _decorated
#      77
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     369         http=self.http)
#     370     except errors.HttpError as error:
# --> 371       raise ApiRequestError(error)
#     372     else:
#     373       self.uploaded = True
#
# ApiRequestError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1irKkQkYNkGqKVMitMGtJtK3nJYbZ8OAX'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content
# modificar"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1tE6ynMLATZl1HJtFGp9KmjmjC292JTNEgyu8BK4ZBtU',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': 'Sheet1!A1:C2',
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['9', '4', '10'], ['4', '2', '7']]
# ******************Data Frame*********************
#    0  1   2
# 0  9  4  10
# 1  4  2   7
